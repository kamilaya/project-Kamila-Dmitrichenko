# %%
import pandas as pd
train_df = pd.read_csv("MoviesOnStreamingPlatforms_updated.csv - Sheet1.csv")
train_df.head(10)
# Out:
#    Unnamed: 0  ID                              Title  Year  Age  IMDb  \
# 0           0   1                          Inception  2010  13+   8.8
# 1           1   2                         The Matrix  1999  18+   8.7
# 2           2   3             Avengers: Infinity War  2018  13+   8.5
# 3           3   4                 Back to the Future  1985   7+   8.5
# 4           4   5     The Good, the Bad and the Ugly  1966  18+   8.8
# 5           5   6  Spider-Man: Into the Spider-Verse  2018   7+   8.4
# 6           6   7                        The Pianist  2002  18+   8.5
# 7           7   8                   Django Unchained  2012  18+   8.4
# 8           8   9            Raiders of the Lost Ark  1981   7+   8.4
# 9           9  10               Inglourious Basterds  2009  18+   8.3
#
#   Rotten Tomatoes  Netflix  Hulu  Prime Video  Disney+  Type  \
# 0             87%        1     0            0        0     0
# 1             87%        1     0            0        0     0
# ...

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16744 entries, 0 to 16743
# Data columns (total 17 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       16744 non-null  int64
#  1   ID               16744 non-null  int64
#  2   Title            16744 non-null  object
#  3   Year             16744 non-null  int64
#  4   Age              7354 non-null   object
#  5   IMDb             16173 non-null  float64
#  6   Rotten Tomatoes  5158 non-null   object
#  7   Netflix          16744 non-null  int64
#  8   Hulu             16744 non-null  int64
#  9   Prime Video      16744 non-null  int64
#  10  Disney+          16744 non-null  int64
#  11  Type             16744 non-null  int64
#  12  Directors        16018 non-null  object
#  13  Genres           16469 non-null  object
#  14  Country          16309 non-null  object
#  15  Language         16145 non-null  object
#  16  Runtime          16152 non-null  float64
# ...

# %%
train_df.describe(include='all')
# Out:
#           Unnamed: 0            ID                                Title  \
# count   16744.000000  16744.000000                                16744
# unique           NaN           NaN                                16744
# top              NaN           NaN  Joe Torre: Curveballs Along The Way
# freq             NaN           NaN                                    1
# mean     8371.500000   8372.500000                                  NaN
# std      4833.720789   4833.720789                                  NaN
# min         0.000000      1.000000                                  NaN
# 25%      4185.750000   4186.750000                                  NaN
# 50%      8371.500000   8372.500000                                  NaN
# 75%     12557.250000  12558.250000                                  NaN
# max     16743.000000  16744.000000                                  NaN
#
#                 Year   Age          IMDb Rotten Tomatoes       Netflix  \
# ...

# %%
print('Mean value of the raiting on IMDb:', train_df['IMDb'].mean())
print('Median of the raiting on IMDb:', train_df['IMDb'].median())
print('Standart deviation of points of the raiting on IMDb:', train_df['IMDb'].std())
# Out:
# Mean value of the raiting on IMDb: 5.902751499412594
# Median of the raiting on IMDb: 6.1
# Standart deviation of points of the raiting on IMDb: 1.3478674621106137

# %%
rint('Mean value of the runtime:', train_df['Runtime'].mean())
print('Median of the runtime:', train_df['Runtime'].median())
print('Standart deviation of the runtime:', train_df['Runtime'].std())
# Out:
# Mean value of the runtime: 93.41344725111442
# Median of the runtime: 92.0
# Standart deviation of the runtime: 28.219222171863148

# %%
sns.pairplot(data, kind='kde', vars=('Netflix','Hulu','Prime Video','Disney+'))

# %%
plt.figure(figsize=(20,9))
plt.hist(train_df['Year'], bins = 30)
plt.xlabel('Year')
plt.ylabel('Number')
plt.title('Statistics of films made in the period from 1900 to 2020')
plt.show()

# %%
plt.figure(figsize = (20,9))
plt.hist(train_df['IMDb'], bins = 30)
plt.xlabel('IMDb')
plt.ylabel('Number')
plt.title('Number of movies with different ratings on IMDb')
plt.show()

# %%
all_netflix = train_df.query ("Age == 'all'")['Netflix']
seven_netflix = train_df.query ("Age == '7+'")['Netflix']
thirteen_netflix = train_df.query ("Age == '13+'")['Netflix']
eighteen_netflix = train_df.query ("Age == '18+'")['Netflix']

all_Hulu = train_df.query ("Age == 'all'")['Hulu']
seven_Hulu = train_df.query ("Age == '7+'")['Hulu']
thirteen_Hulu = train_df.query ("Age == '13+'")['Hulu']
eighteen_Hulu = train_df.query ("Age == '18+'")['Hulu']

all_PrimeVideo = train_df.query ("Age == 'all'")['Prime Video']
seven_PrimeVideo = train_df.query ("Age == '7+'")['Prime Video']
thirteen_PrimeVideo = train_df.query ("Age == '13+'")['Prime Video']
eighteen_PrimeVideo = train_df.query ("Age == '18+'")['Prime Video']

all_Disney = train_df.query ("Age == 'all'")['Disney+']
seven_Disney = train_df.query ("Age == '7+'")['Disney+']
thirteen_Disney = train_df.query ("Age == '13+'")['Disney+']
eighteen_Disney = train_df.query ("Age == '18+'")['Disney+']

print("age restrictions on Netflix: \n\t no age limit: {}%, \n\t seven plus limit: {}%, \n\t thirteen plus limit: {}%, \n\t eighteen plus limit: {}%".format(
    100 * all_netflix.mean(), 100 * seven_netflix.mean(), 100 * thirteen_netflix.mean(), 100 * eighteen_netflix.mean()))
print("age restrictions on Hulu: \n\t no age limit: {}%, \n\t seven plus limit: {}%, \n\t thirteen plus limit: {}%, \n\t eighteen plus limit: {}%".format(
    100 * all_Hulu.mean(), 100 * seven_Hulu.mean(), 100 * thirteen_Hulu.mean(), 100 * eighteen_Hulu.mean()))
print("age restrictions on Prime Video: \n\t no age limit: {}%, \n\t seven plus limit: {}%, \n\t thirteen plus limit: {}%, \n\t eighteen plus limit: {}%".format(
    100 * all_PrimeVideo.mean(), 100 * seven_PrimeVideo.mean(), 100 * thirteen_PrimeVideo.mean(), 100 * eighteen_PrimeVideo.mean()))
print("age restrictions on Disney+: \n\t no age limit: {}%, \n\t seven plus limit: {}%, \n\t thirteen plus limit: {}%, \n\t eighteen plus limit: {}%".format(
    100 * all_Disney.mean(), 100 * seven_Disney.mean(), 100 * thirteen_Disney.mean(), 100 * eighteen_Disney.mean()))
# Out:
# age restrictions on Netflix:
# 	 no age limit: 15.42111506524318%,
# 	 seven plus limit: 22.093023255813954%,
# 	 thirteen plus limit: 30.51792828685259%,
# 	 eighteen plus limit: 21.646516983304547%
# age restrictions on Hulu:
# 	 no age limit: 6.524317912218268%,
# 	 seven plus limit: 7.455540355677155%,
# 	 thirteen plus limit: 9.48207171314741%,
# 	 eighteen plus limit: 8.347725964306276%
# age restrictions on Prime Video:
# 	 no age limit: 48.16132858837485%,
# 	 seven plus limit: 62.653898768809846%,
# 	 thirteen plus limit: 65.25896414342628%,
# 	 eighteen plus limit: 75.18710420264824%
# age restrictions on Disney+:
# 	 no age limit: 32.858837485172%,
# 	 seven plus limit: 12.243502051983585%,
# 	 thirteen plus limit: 3.187250996015936%,
# 	 eighteen plus limit: 0.08635578583765112%

# %%
runtime_90 = train_df.query("Runtime <= 90")
runtime_120 = train_df.query("90 < Runtime <= 120")
runtime_150 = train_df.query("120 < Runtime <= 150")
runtime_180 = train_df.query("150 < Runtime <= 180")
runtime_big = train_df.query("Runtime > 180")

indices_90 = runtime_90['Rotten Tomatoes'] >= "50%"
filter_90 = runtime_90['Rotten Tomatoes'][indices_90]

indices_120 = runtime_120['Rotten Tomatoes'] >= "50%"
filter_120 = runtime_120['Rotten Tomatoes'][indices_120]

indices_150 = runtime_150['Rotten Tomatoes'] >= "50%"
filter_150 = runtime_150['Rotten Tomatoes'][indices_150]

indices_180 = runtime_180['Rotten Tomatoes'] >= "50%"
filter_180 = runtime_180['Rotten Tomatoes'][indices_180]

indices_big = runtime_big['Rotten Tomatoes'] >= "50%"
filter_big = runtime_big['Rotten Tomatoes'][indices_big]

print('The number of films with a high rating on Rotten Tomatoes that duration is less than 90:', len(filter_90))
print('The number of films with a high rating on Rotten Tomatoes that duration is less than 120:', len(filter_120))
print('The number of films with a high rating on Rotten Tomatoes that duration is less than 150:', len(filter_150))
print('The number of films with a high rating on Rotten Tomatoes that duration is less than 180:', len(filter_180))
print('The number of films with a high rating on Rotten Tomatoes that duration is more than 180:', len(filter_big))
# Out:
# The number of films with a high rating on Rotten Tomatoes that duration is less than 90: 998
# The number of films with a high rating on Rotten Tomatoes that duration is less than 120: 1878
# The number of films with a high rating on Rotten Tomatoes that duration is less than 150: 369
# The number of films with a high rating on Rotten Tomatoes that duration is less than 180: 76
# The number of films with a high rating on Rotten Tomatoes that duration is more than 180: 21

# %%
During this data analysis I have found mean value, median and standart deviation of the rating om IMBd, one of the best American
review sites. Moreover, the mean value, median and standart devitation of the films'' runtime were found. There are three graphs:
the first kde graph shows the pendence between the four platforms for watching movies: Netflix, Hulu, Prime Vdeo, Disney+, the 
second graph that calls histogram depicts the stics of films made in the period from 1900 to 2020, and it is easy to see that
in the period between 2012 and 2016 the biggest amount of films were made, the third graph in this data analyse shows the 
nmber of movies with different ratings on IMDb, and it seems that the majority of films has rating approximately 6.2.
One of the last steps of analysis was the counting of persentage of different age limits on different film plaforms. That is why
we can see that Netflix and Hulu are platformsfor teenagers, because the majority of their films are with the rating 13+, Prime
Video is an adult platform, because more than 50% of the films there have 18+ limit, and it is clear that DIsney+ is the platform
for kids, because practically all films there have no age limit. On the last step of analysis I found which films of different
duration are on the top of Rotten Tomatoes rating. It was found that the biggest number of high-rated films are continued for less
than 120 minutes.
